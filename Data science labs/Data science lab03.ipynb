# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_csv=pd.read_csv('/content/iris.csv')
df_csv.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df_csv.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
#seaborn scatter plot
sns.scatterplot(data=df_csv,x='sepal_width',y='sepal_length',style='species',palette='coolwarm')
plt.title('sepal_length vs sepal_width (seaborn)')
plt.show()
# Out:
# <ipython-input-18-4ba3795f2b81>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df_csv,x='sepal_width',y='sepal_length',style='species',palette='coolwarm')

# %%
species_counts=df('species').value_counts()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)

# %%
plt.figure(figsize=(10,6))
correlation_matrix=df_csv.select_dtypes(include=['number']).corr()
sns.heatmap(correlation_matrix,annot=true,cmp='viridis',fmt='coolwarm',vmin=-1,vmax=1)

plt.title('correlation heatmap(seaborn)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3884052d5d6b> in <cell line: 3>()
#       1 plt.figure(figsize=(10,6))
#       2 correlation_matrix=df_csv.select_dtypes(include=['number']).corr()
# ----> 3 sns.heatmap(correlation_matrix,annot=true,cmp='viridis',fmt='coolwarm',vmin=-1,vmax=1)
#       4
#       5 plt.title('correlation heatmap(seaborn)')
#
# NameError: name 'true' is not defined
