# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
pop_mean = 100
pop_sd = 15
visitors = np.random.randint(5, 200, size=50)
print(visitors)
sample_mean = np.mean(visitors)
sample_size = len(visitors)
z_score_calculated = (sample_mean-pop_mean)/(pop_sd/np.sqrt(sample_size))
alpha = 0.05
z_critical= stats.norm.ppf(1-alpha/2)
# Out:
# [  5 191 171 113  67 158  54 165 146  67  38 145  40 198 199  92 112 112
#   98  52  37  96 113 129 171  92  36 174  22 150   9 147 190 183  56 144
#   53  71 110  16 158  10  23 160 163  56  11 151  41  11]

# %%
print(f"calculated z-score:{z_score_calculated:3f}")
print("critical z-value: {Z_CRITICAL:.3f}")
# Out:
# calculated z-score:0.056569
# critical z-value: {Z_CRITICAL:.3f}

# %%
if z_score_calculated > z_critical or  z_score_calculated < -z_critical:
    print("conclusion: Reject the null hypothesis.the sample mean is not significantly different from population mean.")
else:
    print("conclusion:fail to reject the null hypothesis. the sample mean is not significantly different from population mean.")
# Out:
# conclusion:fail to reject the null hypothesis. the sample mean is not significantly different from population mean.

# %%
visitors = np.random.randint(5, 200, size=20)
print(visitors)
pop_mean = 150
sample_mean = np.mean(visitors)
sample_std = np.std(visitors,ddof=1)
#Here ddof=1 tells numpy to use n-1 when calculating thestandard which is necessary for the sample data.we use ddof =0 for population deviation.
n=len(visitors)
 df = n-1
 t_calc,_=stats.ttest_1samp(visitors,popmean =pop_mean)
 alpha = 0.05
 t_critical=stats.t.ppf(1- alpha/ 2, df)
 print(f"sample mean :")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a sample signal with multiple frequencies (for example: a sum of sine waves)
sampling_rate = 1000  # samples per second
duration = 1  # seconds
t = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)  # time vector

# Create a signal that contains two frequencies: 50Hz and 120Hz
signal = 3 * np.sin(2 * np.pi * 50 * t) + 1.5 * np.sin(2 * np.pi * 120 * t)

# Perform Fourier Transform (FFT)
fft_signal = np.fft.fft(signal)

# Get the frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(t), 1/sampling_rate)

# Take the absolute value of the FFT to get the magnitude
magnitude = np.abs(fft_signal)

# Only plot the positive frequencies (real part) for clarity
positive_frequencies = frequencies[:len(frequencies)//2]
positive_magnitude = magnitude[:len(magnitude)//2]

# Plot the original signal
plt.figure(figsize=(12, 6))

# Subplot 1: Time-domain signal
plt.subplot(2, 1, 1)
plt.plot(t, signal)
plt.title('Original Signal (Time Domain)')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')

# Subplot 2: Frequency-domain (FFT result)
plt.subplot(2, 1, 2)
plt.plot(positive_frequencies, positive_magnitude)
plt.title('Fourier Transform (Frequency Domain)')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')

plt.tight_layout()
plt.show()
