# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
np.random.seed(42)
population_size =100000
sample_sizes=[3,5,7,25,75,100]
population=np.random.exponential(scale=2,size=population_size)
plt.figure(figsize=(10,6))
sns.histplot(population,bins=50,kde=True,color='#33FFF9')
plt.title('population distribution',fontsize=16)
plt.xlabel('value')
plt.ylabel('frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
for i ,size in enumerate(sample_size,start=1):
  sample_mean=[np.mean(np.random.choice(population,size=size,replace=False))for _ in range(num_sample)]
  print(i)
  print(size)
  print(sample_mean)
  plt.subplot(3,2,i)
  sns.histplot(sample_mean,bins=60,kde=true,color="red",alpha=0.7)
  plt.axvline(np.mean(population),color='blue',linestyle='dashed',linewidth=2)
  plt.title(f'sample size={size}')
  plt.xlabel('mean')
  plt.ylabel('frequency')
  plt.suptitle('distribution of central means theorem',fontsize=16)
  plt.tight_layout
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a2c3aeaa9eb2> in <cell line: 2>()
#       1 plt.figure(figsize=(10,6))
# ----> 2 for i ,size in enumerate(sample_size,start=1):
#       3   sample_mean=[np.mean(np.random.choice(population,size=size,replace=False))for _ in range(num_sample)]
#       4   print(i)
#       5   print(size)
#
# NameError: name 'sample_size' is not defined
